# %% [markdown]
# <h1>Your best HOLIDAYS in your life<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Where-do-you-prefer-spent-your-holidays??" data-toc-modified-id="Where-do-you-prefer-spent-your-holidays??-1"><span class="toc-item-num">1&nbsp;&nbsp;</span><span style="color: green">Where do you prefer spent your holidays??</span></a></span><ul class="toc-item"><li><span><a href="#Now-we-tried-to-know-you-a-littel-more,-to-propose-you-some-beautiful-places-to-spent-your-holidays." data-toc-modified-id="Now-we-tried-to-know-you-a-littel-more,-to-propose-you-some-beautiful-places-to-spent-your-holidays.-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span><span style="color: gray"><strong>Now we tried to know you a littel more, to propose you some beautiful places to spent your holidays.</strong></span></a></span></li><li><span><a href="#Let-me-know-anymore-about-your-preferences." data-toc-modified-id="Let-me-know-anymore-about-your-preferences.-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span><span style="color: gray"><strong>Let me know anymore about your preferences.</strong></span></a></span></li><li><span><a href="#Destinations:" data-toc-modified-id="Destinations:-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span><span style="color: gray"><em>Destinations:</em></span></a></span><ul class="toc-item"><li><span><a href="#Let-me-show-the-first-one" data-toc-modified-id="Let-me-show-the-first-one-1.3.1"><span class="toc-item-num">1.3.1&nbsp;&nbsp;</span><span style="color: blue"><strong>Let me show the first one</strong></span></a></span></li><li><span><a href="#And-finally,-I-think-this-is-awsome" data-toc-modified-id="And-finally,-I-think-this-is-awsome-1.3.2"><span class="toc-item-num">1.3.2&nbsp;&nbsp;</span><span style="color: blue"><strong>And finally, I think this is awsome</strong></span></a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# # <span style='color:green'>Where do you prefer spent your holidays??</span>

# %% [markdown]
# ## <span style='color:gray '>**Now we tried to know you a littel more, to propose you some beautiful places to spent your holidays.**</span>

# %%
q= "Juan"
w= "Rosa"
e= "Eva"
r= "Felipe"
x=input("Hello, I like to know if you are Juan, Rosa, Eva or Felipe:").lower().title()
print("Hello:", x)
# Out:
# Hello, I like to know if you are Juan, Rosa, Eva or Felipe:eva
# Hello: Eva

# %%
from IPython.display import Image
from IPython.core.display import HTML 

if x== r :
    display(Image(url="https://github.com/RexTor78/JupiterLab/blob/master/Images/dog.jpg?raw=true", width=100, height=100))
elif x== w :
    display(Image(url="https://raw.githubusercontent.com/RexTor78/JupiterLab/master/Images/d1.jpg", width=100, height=100))
elif x== e :
    display(Image(url="https://github.com/RexTor78/JupiterLab/blob/master/Images/d2.jpg?raw=true", width=100, height=100))
elif x== q :
    display(Image(url="https://github.com/RexTor78/JupiterLab/blob/master/Images/d3.jpg?raw=true", width=100, height=100))
else:
    print("I'm sorry I don't know who are you, I need some data about you.")
# Out:
# <img src="https://github.com/RexTor78/JupiterLab/blob/master/Images/d2.jpg?raw=true" width="100" height="100"/>

# %% [markdown]
# ## <span style='color:gray '>**Let me know anymore about your preferences.**</span>

# %%
a= "Mountain"
b= "Beach"
c= "Resort"
d= "Camping"
f= "Hotel"
j= "relax"
l=" sport" or "adventure"
y= input("Now I like what do you prefer, Mountain or Beach :  ").lower().title()
z= input("And do you prefer stay in a Resort, in a Camping or in a Hotel: ").lower().title()
v= input ("And finallly would you relax or do any adventure, sport in this holidays :  ").lower().title()
# Out:
# Now I like what do you prefer, Mountain or Beach :  beach
# And do you prefer stay in a Resort, in a Camping or in a Hotel: hotel
# And finallly would you relax or do any adventure, sport in this holidays :  Sport

# %%
from IPython.display import Image
from IPython.core.display import HTML 
if y==a and z==c:
    display(Image(url="https://github.com/RexTor78/JupiterLab/blob/master/Images/MR.jpg?raw=true"))
elif y==a and z==d:
    display(Image(url="https://github.com/RexTor78/JupiterLab/blob/master/Images/CM.jpg?raw=true"))
elif y==a and z==f:
    display(Image(url="https://github.com/RexTor78/JupiterLab/blob/master/Images/HM.jpg?raw=true"))
elif  y==b and z==c:
    display(Image(url="https://github.com/RexTor78/JupiterLab/blob/master/Images/BR.jpg?raw=true"))
elif y==b and z==d:
    display(Image(url="https://github.com/RexTor78/JupiterLab/blob/master/Images/CB.jpg?raw=true"))
elif y==b and z==f:
    display(Image(url="https://github.com/RexTor78/JupiterLab/blob/master/Images/HB.jpg?raw=true"))
else:
    print("Option not available, please choose one of the options available.")
# Out:
# <img src="https://github.com/RexTor78/JupiterLab/blob/master/Images/HB.jpg?raw=true"/>

# %%
if v==j:
    display(Image(url="https://github.com/RexTor78/JupiterLab/blob/master/Images/Relax.jpg?raw=true"))
else:
    display(Image(url="https://github.com/RexTor78/JupiterLab/blob/master/Images/sport.jpg?raw=true"))
# Out:
# <img src="https://github.com/RexTor78/JupiterLab/blob/master/Images/sport.jpg?raw=true"/>

# %% [markdown]
#  <span style='color:blue '>_Ummm very cool, I think I have two beautiful places for you and I'm sure you like a lot._</span>

# %% [markdown]
# ## <span style='color:gray '>_Destinations:_</span>

# %% [markdown]
# ### <span style='color:blue '>__Let me show the first one__</span>

# %%
from IPython.display import YouTubeVideo

YouTubeVideo('F8xjqCyTPbA', width=800, height=300)

# %% [markdown]
# ### <span style='color:blue '>__And finally, I think this is awsome__</span>

# %%
from IPython.display import YouTubeVideo

YouTubeVideo('srFKQrmL3Fg', width=800, height=300)
