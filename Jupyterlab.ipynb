# %% [markdown]
# # Where do you prefer spent your holidays??

# %% [markdown]
# ## **Now we tried to know you to propose some beautiful places to spent your holidays.**

# %%
q= "Juan"
w= "Rosa"
e= "Eva"
r= "Felipe"
x= input("Hello, I like to know if you are Juan, Rosa, Eva or Felipe:")  
print("Hello:", x)
# Out:
# Hello, I like to know if you are Juan, Rosa, Eva or Felipe:Eva
# Hello: Eva

# %%
from IPython.display import Image
from IPython.core.display import HTML 

if x== r :
    Image(url="https://github.com/RexTor78/JupiterLab/blob/e4e35c19aa0276a8f0d5fb04cba822fa6fac90f7/Images/dog.jpg")

    if x== w :
        Image(url="https://github.com/RexTor78/JupiterLab/blob/e4e35c19aa0276a8f0d5fb04cba822fa6fac90f7/Images/d2.jpg")

    if x== e :
        Image(url="https://github.com/RexTor78/JupiterLab/blob/e4e35c19aa0276a8f0d5fb04cba822fa6fac90f7/Images/d1.jpg")
 
    if x== q :
        Image(url="https://github.com/RexTor78/JupiterLab/blob/e4e35c19aa0276a8f0d5fb04cba822fa6fac90f7/Images/d3.jpg")

# %%
a= "Mountain"
b= "Beach"
c= "Resort"
d= "Camping"
f= "Hotel"
j= "relax"
l=" sport" or "adventure"
y= input("Now I like what do you prefer, Mountain or Beach :  ")
z= input("And do you prefer stay in a Resort, in a Camping or in a Hotel: ")
v= input ("And finallly would you relax or do any adventure, sport in this holidays :  ")
# Out:
# Now I like what do you prefer, Mountain or Beach :  mountain
# And do you prefer stay in a Resort, in a Camping or in a Hotel: hotel
# And finallly would you relax or do any adventure, sport in this holidays :  sport

# %%
from IPython.display import Image
from IPython.core.display import HTML 
if y==a and z==c
    Image(url="https://github.com/RexTor78/JupiterLab/blob/e116da05558a1b527b6ab16d207b861cb574a362/Images/MR.jpg")
    if y==a and z==d
    Image(url="https://github.com/RexTor78/JupiterLab/blob/e116da05558a1b527b6ab16d207b861cb574a362/Images/CM.jpg")
    if y==a and z==f
    Image(url="https://github.com/RexTor78/JupiterLab/blob/e116da05558a1b527b6ab16d207b861cb574a362/Images/HM.jpg")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-c46e5eb0377f> in <module>
#       3 if y==a+c:
#       4     base64_data2 ="..."
# ----> 5 display.Image(b64decode(base64_data))
#
# NameError: name 'base64_data' is not defined
